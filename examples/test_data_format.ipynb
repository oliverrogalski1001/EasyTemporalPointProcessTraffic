# %%
import pickle

with open("data/traffic_week/test.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data["test"][0]
# Out:
# [{'idx_event': 1,
#   'time_since_last_event': 0.00027778,
#   'time_since_last_same_event': 0.00027778,
#   'type_event': 0,
#   'time_since_start': 0.00027778},
#  {'idx_event': 2,
#   'time_since_last_event': 0.00027778,
#   'time_since_last_same_event': 0.00027778,
#   'type_event': 0,
#   'time_since_start': 0.00055556},
#  {'idx_event': 3,
#   'time_since_last_event': 0.00027778,
#   'time_since_last_same_event': 0.00027778,
#   'type_event': 0,
#   'time_since_start': 0.00083333},
#  {'idx_event': 4,
#   'time_since_last_event': 0.00027778,
#   'time_since_last_same_event': 0.00027778,
#   'type_event': 0,
#   'time_since_start': 0.00111111},
#  {'idx_event': 5,
#   'time_since_last_event': 0.08333333,
#   'time_since_last_same_event': 0.08333333,
#   'type_event': 0,
#   'time_since_start': 0.08444444},
#  {'idx_event': 6,
#   'time_since_last_event': 0.00027778,
#   'time_since_last_same_event': 0.00027778,
#   'type_event': 0,
#   'time_since_start': 0.08472222},
# ...

# %%
with open("data/taxi/test.pkl", "rb") as f:
    taxi = pickle.load(f)

taxi["test"][0]
# Out:
# [{'idx_event': 1,
#   'type_event': 8,
#   'time_since_start': 0.0,
#   'time_since_last_event': 0.0},
#  {'idx_event': 2,
#   'type_event': 3,
#   'time_since_start': 0.2936111111111111,
#   'time_since_last_event': 0.2936111111111111},
#  {'idx_event': 3,
#   'type_event': 8,
#   'time_since_start': 0.5283333333333333,
#   'time_since_last_event': 0.23472222222222222},
#  {'idx_event': 4,
#   'type_event': 3,
#   'time_since_start': 0.595,
#   'time_since_last_event': 0.06666666666666665},
#  {'idx_event': 5,
#   'type_event': 8,
#   'time_since_start': 0.6202777777777778,
#   'time_since_last_event': 0.025277777777777843},
#  {'idx_event': 6,
#   'type_event': 3,
#   'time_since_start': 0.7705555555555555,
#   'time_since_last_event': 0.15027777777777773},
#  {'idx_event': 7,
#   'type_event': 8,
#   'time_since_start': 0.8825,
#   'time_since_last_event': 0.1119444444444444},
#  {'idx_event': 8,
#   'type_event': 3,
#   'time_since_start': 1.0363888888888888,
# ...
